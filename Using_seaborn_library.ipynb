# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarupriya1998/Data-Analytics-projects/blob/main/Using_seaborn_library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Load the exam.csv dataset into a DataFrame and perform the following tasks on the “math score,” ”readingscore,” and “writing score” columns:
# 1.Plot the distributions using the seabornlibrary.
# 2.Find the mean and standard deviation using the scipylibrary.
# 3.Find skewness and kurtosisusing thestatsmodule from the scipylibrary.
# 4.Find Standard Normal Distribution(z-score) using the statsmodule from the scipylibrary.
# 5.Plot the Z distribution using the seabornlibrary.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
df=pd.read_csv("exam.csv")
df

# %% [markdown]
# 1.Plot the distributions using the seaborn library

# %%
cols=['math score','reading score','writing score']
fig,ax=plt.subplots(1,3,figsize=[15,5])
for variable,subplot in zip(cols,ax.flatten()):
  plot=sns.distplot(x=df[variable],ax=subplot,hist=False)
  plot.set_xlabel(variable,fontsize=15)
plt.tight_layout()

# %% [markdown]
# 2.Find the mean and standard deviation using the scipy library

# %%
import scipy 
for i in cols:
  print('\n')
  print('Mean of',i,':',scipy.mean(df[i]))
  print('Standard Deviation of',i,':',scipy.std(df[i]))

# %% [markdown]
# 3.Find skewness and kurtosis using the stats module from the scipy library.

# %%
from scipy import stats
for i in cols:
  sk=stats.skew(df[i])
  print('\n')
  print('The skewness of',i,':',sk)
  ku=stats.kurtosis(df[i])
  print('\n')
  print('The kurtosis of',i,':',ku)

# %% [markdown]
# 4.Find Standard Normal Distribution (z-score)using the stats module from the scipy library

# %%
for i in cols:
  zs=stats.zscore(df[i],axis=0)
  print('\n')
  print('The z-score of',i,':',zs)

# %% [markdown]
# 5.Plot the z-distribution using the seaborn library

# %%
fig,ax=plt.subplots(1,3,figsize=[15,5])
for variable,subplot in zip(cols,ax.flatten()):
  plot=sns.distplot(x=df[variable],ax=subplot,hist=False)
  plot.set_xlabel(variable,fontsize=15)
plt.tight_layout()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...
